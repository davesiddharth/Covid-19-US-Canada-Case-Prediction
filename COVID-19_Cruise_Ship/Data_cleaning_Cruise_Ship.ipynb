# %%
#Importing the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Storing the csvpaths
csvpath_confirmed="time_series_19-covid-Confirmed.csv"
csvpath_death="time_series_19-covid-Deaths.csv"
csvpath_recovered="time_series_19-covid-Recovered.csv"

# %%
#Reading into a pandas DataFrame
confirmed_df=pd.read_csv(csvpath_confirmed)
death_df=pd.read_csv(csvpath_death)
recovered_df=pd.read_csv(csvpath_recovered)

# %%
#Manipulating the Confirmed dataframe
#Dropping the colums which are not required
confirmed_df.drop(columns=["Province/State","Lat","Long"],inplace=True)

# %%
#Filling NaN with a 0 for calculations
confirmed_df=confirmed_df.fillna(0)
confirmed_df.head()
#len(Confirmed_df1
confirmed_df["Country/Region"]
# Out:
# 0                 Thailand
# 1                    Japan
# 2                Singapore
# 3                    Nepal
# 4                 Malaysia
#               ...
# 416                  Aruba
# 417                 Canada
# 418                  Kenya
# 419    Antigua and Barbuda
# 420                     US
# Name: Country/Region, Length: 421, dtype: object

# %%
#Grouping the Confirmed cases dataframe by Country/Region
confirmed_group=confirmed_df.groupby(["Country/Region"])


#Creating the final Confirmed dataframe to be used further
confirmed_final=confirmed_group.sum()
confirmed_final.head()
#len(Confirmed_final)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  3/4/20  3/5/20  \
# Country/Region                                           ...
# Afghanistan                0        0        0        0  ...       1       1
# Albania                    0        0        0        0  ...       0       0
# Algeria                    0        0        0        0  ...      12      12
# Andorra                    0        0        0        0  ...       1       1
# ...

# %%
#Manipulating the Deaths dataframe
#Dropping the colums which are not required
death_df.drop(columns=["Province/State","Lat","Long"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-6857379be090> in <module>
#       1 #Manipulating the Deaths dataframe
#       2 #Dropping the colums which are not required
# ----> 3 death_df.drop(columns=["Province/State","Lat","Long"],inplace=True)
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3992             level=level,
#    3993             inplace=inplace,
# -> 3994             errors=errors,
#    3995         )
#    3996
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3933         for axis, labels in axes.items():
#    3934             if labels is not None:
# ...

# %%
#Filling NaN with a 0 for calculations
death_df=death_df.fillna(0)
death_df.head()
#len(Confirmed_df1)

# %%
#Grouping the Death cases dataframe by Country/Region
death_group=death_df.groupby(["Country/Region"])


#Creating the final Death dataframe to be used further
death_final=death_group.sum()
death_final.head()
#len(Deaths_final)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  3/4/20  3/5/20  \
# Country/Region                                           ...
# Afghanistan                0        0        0        0  ...       0       0
# Albania                    0        0        0        0  ...       0       0
# Algeria                    0        0        0        0  ...       0       0
# Andorra                    0        0        0        0  ...       0       0
# ...

# %%
#Manipulating the Recovered dataframe
#Dropping the colums which are not required
recovered_df.drop(columns=["Province/State","Lat","Long"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-31fb98399339> in <module>
#       1 #Manipulating the Recovered dataframe
#       2 #Dropping the colums which are not required
# ----> 3 recovered_df.drop(columns=["Province/State","Lat","Long"],inplace=True)
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3992             level=level,
#    3993             inplace=inplace,
# -> 3994             errors=errors,
#    3995         )
#    3996
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3933         for axis, labels in axes.items():
#    3934             if labels is not None:
# ...

# %%
#Filling NaN with a 0 for calculations
recovered_df=recovered_df.fillna(0)
recovered_df.head()
#len(Recovered_df1)
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0       Thailand        0        0        0        0        2        2
# 1          Japan        0        0        0        0        1        1
# 2      Singapore        0        0        0        0        0        0
# 3          Nepal        0        0        0        0        0        0
# 4       Malaysia        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  3/4/20  3/5/20  3/6/20  3/7/20  3/8/20  \
# 0        5        5        5  ...      31      31      31      31      31
# 1        1        1        1  ...      43      43      46      76      76
# 2        0        0        0  ...      78      78      78      78      78
# 3        0        0        0  ...       1       1       1       1       1
# 4        0        0        0  ...      22      22      22      23      24
#
#    3/9/20  3/10/20  3/11/20  3/12/20  3/13/20
# 0      31       33       34       34       35
# ...

# %%
#Grouping the Recovered cases dataframe by Country/Region
recovered_group=recovered_df.groupby(["Country/Region"])


#Creating the final Recovered dataframe to be used further
recovered_final=recovered_group.sum()
recovered_final.head(110)
#len(Recovered_final)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# ...                      ...      ...      ...      ...      ...      ...
# Serbia                     0        0        0        0        0        0
# Singapore                  0        0        0        0        0        0
# Slovakia                   0        0        0        0        0        0
# Slovenia                   0        0        0        0        0        0
# South Africa               0        0        0        0        0        0
#
# ...

# %%
total_date = len(recovered_final.loc["Cruise Ship"])

# %%
#Creating a dataframe for South Korea
cruise_df=pd.DataFrame({"Date":confirmed_final.loc["Cruise Ship",:].index.tolist(),\
                           "Cumulative Confirmed":confirmed_final.loc["Cruise Ship",:].tolist(),\
                           "Cumulative Death":death_final.loc["Cruise Ship",:].tolist(),
                           "Cumulative Recovered":recovered_final.loc["Cruise Ship",:].tolist()})

# %%
cruise_df.head(20)
# Out:
#        Date  Cumulative Confirmed  Cumulative Death  Cumulative Recovered
# 0   1/22/20                     0                 0                     0
# 1   1/23/20                     0                 0                     0
# 2   1/24/20                     0                 0                     0
# 3   1/25/20                     0                 0                     0
# 4   1/26/20                     0                 0                     0
# 5   1/27/20                     0                 0                     0
# 6   1/28/20                     0                 0                     0
# 7   1/29/20                     0                 0                     0
# 8   1/30/20                     0                 0                     0
# 9   1/31/20                     0                 0                     0
# 10   2/1/20                     0                 0                     0
# 11   2/2/20                     0                 0                     0
# ...

# %%
confirmed_total_cruise=max(cruise_df["Cumulative Confirmed"])
confirmed_total_cruise
# Out:
# 706

# %%
death_total_cruise = max(cruise_df["Cumulative Death"])
death_total_cruise
# Out:
# 7

# %%
recovered_total_cruise=max(cruise_df["Cumulative Recovered"])
recovered_total_cruise
# Out:
# 325

# %%
cruise_guest = 2666
cruise_crew = 1045
total_population_cruise = cruise_guest + cruise_crew
#total population in south korea

# %%
#% of Death=Total Death/Total confirmed *100
#% of Recovered=Total Recovered/Total confirmed *100
#Infection rate=Total confirmed/Total population *100
#Speed of Infection=Total Confirmed/Total days

infection_rate_cruise = round((confirmed_total_cruise/total_population_cruise)*100,5)
#infection_rate_cruise_ship

percentage_death_cruise = round((death_total_cruise/confirmed_total_cruise)*100,2)
#percentage_death_cruise_ship

percentage_recovered_cruise = round((recovered_total_cruise/confirmed_total_cruise)*100,2)
#percentage_recovered_cruise_ship


speed_infection_cruise = round((confirmed_total_cruise/total_days),1)
speed_infection_cruise
# Out:
# 19.6

# %%
plt.figure(figsize=(20, 5))
x_axis = cruise_df["Date"]
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
plt.title("Cumulative Covid-19 Cases in Diamond Princess Cruise Ship")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.grid()
    
confirmed_cases, = plt.plot(x_axis, cruise_df.loc[:,'Cumulative Confirmed'], color="blue", label="Cumulative Confirmed Cases")
death_cases, = plt.plot(x_axis, cruise_df.loc[:,'Cumulative Death'], color="red", label="Cumulative Death Cases")
recovered_cases, = plt.plot(x_axis, cruise_df.loc[:,'Cumulative Recovered'], color="green", label="Cumulative Recovered Cases")

plt.legend(handles=[confirmed_cases, death_cases,recovered_cases], loc="upper left")
plt.xticks(tick_locations,rotation = 80)

start_day = 1

plt.xlim(start_day, total_date-1)
plt.savefig("Cumulative Cases for cruise ship.jpg")
plt.show()
len(cruise_df)
# Out:
# 52

# %%
print(f"{round(speed_infection_cruise,0)} people per day got infected throughout {total_days} days.")
print(f"The rate at which the population got infected from 22nd Jan 2020 to 13th March 2020 was {infection_rate_cruise}.")
print(f"{percentage_death_cruise}% population suffered death from 22nd Jan 2020 to 13th March 2020.")
print(f"{percentage_recovered_cruise}% population recovered from 22nd Jan 2020 to 13th March 2020.")
print(f"{infection_rate_cruise}% people got infected out of the entire population of {total_population_cruise}.")
# Out:
# 20.0 people per day got infected throughout 36 days.
# The rate at which the population got infected from 22nd Jan 2020 to 13th March 2020 was 19.02452.
# 0.99% population suffered death from 22nd Jan 2020 to 13th March 2020.
# 46.03% population recovered from 22nd Jan 2020 to 13th March 2020.
# 19.02452% people got infected out of the entire population of 3711.

# %%
# Calculating the increase in confirmed cases per day 
cruise_df["Date"]
cumulative_cases =cruise_df["Cumulative Confirmed"]
difference_cruise = np.diff(cumulative_cases)
daily_cruise= np.concatenate([np.array([difference_cruise[0]]), difference_cruise])

# %%
difference_cruise.tolist()
cruise_daily_df=pd.DataFrame({"Date":cruise_df["Date"].tolist(),\
                           "Daily Confirmed":daily_cruise.tolist()
                           })
cruise_daily_df.head()
# Out:
#       Date  Daily Confirmed
# 0  1/22/20                0
# 1  1/23/20                0
# 2  1/24/20                0
# 3  1/25/20                0
# 4  1/26/20                0

# %%
# Plot the daily updates in South Korea

plt.figure(figsize=(20, 5))
x_axis = cruise_daily_df["Date"]
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
plt.title("Daily Updates of Covid-19 Cases in Cruise Ship ")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.grid()
    
confirmed_cases, = plt.plot(x_axis, cruise_daily_df.loc[:,'Daily Confirmed'], color="blue", label="Daily Confirmed Cases")

plt.legend(handles=[confirmed_cases], loc="upper left")
plt.xticks(tick_locations, rotation = 80)
plt.xlim(1, len(cruise_daily_df)-1)
plt.savefig("Daily Updated Cases for Cruise Ship.jpg")
plt.show()
